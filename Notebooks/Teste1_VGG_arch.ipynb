# %% [markdown]
# Testa a eficiencia de uma arquitetura Baseada na VGG em diferenciar frames de Tomografia Computadorizada (CT) contendo infecção por COVID de frames de Pulmões saldáveis
# ---

# %%
# Monta o drive para ler os dados salvos no mesmo
from google.colab import drive

drive.mount("/content/gdrive")
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# !pip3 install pickle5
import pickle5 as pickle
# Out:
# Requirement already satisfied: pickle5 in /usr/local/lib/python3.7/dist-packages (0.0.11)

# %%
# Importa as bibliotecas necessárias
import os
#import pickle
import cv2
import nibabel as nib
import numpy as np

import tensorflow as tf
from tensorflow.keras import Model,layers
from tensorflow.keras.models import Sequential
from tensorflow.keras import applications

import matplotlib.pyplot as plt

# %%
# Normaliza as imagens
def normImage(image):
    image-=np.min(image)
    image = (image/np.max(image))*255
    return image.astype('uint8')

# %%
# Função para gerar o modelo
def get_model(IMG_HEIGHT, IMG_WIDTH, CHANNELS,ini_filter = 64):
    in1 = layers.Input(shape=(IMG_HEIGHT, IMG_WIDTH, CHANNELS ))
        
    
    #layers convolucionais baseados na U-net
    conv1 = layers.Conv2D(int(ini_filter), (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(in1)
    conv1 = layers.Dropout(0.2)(conv1)
    pool1 = layers.MaxPooling2D((2, 2))(conv1) #128

    conv2 = layers.Conv2D(int(ini_filter*2), (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(pool1)
    conv2 = layers.Dropout(0.2)(conv2)
    pool2 = layers.MaxPooling2D((2, 2))(conv2) #64

    conv3 = layers.Conv2D(int(ini_filter*4), (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(pool2)
    conv3 = layers.Dropout(0.2)(conv3)
    pool3 = layers.MaxPooling2D((2, 2))(conv3) #32

    conv4 = layers.Conv2D(int(ini_filter*4), (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(pool3)
    conv4 = layers.Dropout(0.2)(conv4)
    pool4 = layers.MaxPooling2D((2, 2))(conv4) #16
    
    flat1 = layers.Flatten()(pool4)
 
    output = layers.Dense(2, activation='softmax',name='out')(flat1)
    
    model = Model(inputs=[in1], outputs=[output])

    losses = {'out': 'binary_crossentropy'}

    metrics = {'out': ['acc']}

    model.compile(optimizer="adam", loss = losses, metrics=metrics)

    return model

# %%
#carregar os dados
with open(os.path.join('/content/gdrive/MyDrive/dados',
                       'covid_set_256x256_raw.pickle'), 'rb') as handle:
    covid_set = pickle.load(handle)

# %%
# Remodelar os dados para o treino
X_train = np.array(covid_set['X_train']).reshape((-1,256,256,1))
y_train = np.array(covid_set['y_train']).reshape((-1,1))
X_test = np.array(covid_set['X_test']).reshape((-1,256,256,1))
y_test = np.array(covid_set['y_test']).reshape((-1,1))
y_train = np.hstack((y_train,1-y_train))
y_test = np.hstack((y_test,1-y_test))

# %%
# Mostrar parte do dataset
# 1 -> Covid || 0-> Saudável
for i in range(1,502,100):
    fig, (ax1, ax2) = plt.subplots(1, 2)
    ax1.imshow(X_train[i-1,:,:,0])
    ax1.set_title(str(y_train[i-1,0]))
    
    ax2.imshow(X_train[i,:,:,0])
    ax2.set_title(str(y_train[i,0]))

# %%
# Liberar um pouco de memória
del covid_set

# %%
# criar modelo
model = get_model(IMG_HEIGHT=256, 
                  IMG_WIDTH=256, 
                  CHANNELS=1)

# Treinar o modelo
EPOCHS=20
BATCH_SIZE=32
history = model.fit(X_train, y_train , epochs=EPOCHS, 
                    batch_size = BATCH_SIZE,shuffle=True, 
                    validation_data=(X_test, y_test))
# Out:
# Epoch 1/20
# 40/40 [==============================] - 9s 207ms/step - loss: 1.6698 - acc: 0.5607 - val_loss: 0.6726 - val_acc: 0.6195
# Epoch 2/20
# 40/40 [==============================] - 8s 202ms/step - loss: 0.6424 - acc: 0.6286 - val_loss: 0.6935 - val_acc: 0.5440
# Epoch 3/20
# 40/40 [==============================] - 8s 202ms/step - loss: 0.6299 - acc: 0.6366 - val_loss: 0.6764 - val_acc: 0.5629
# Epoch 4/20
# 40/40 [==============================] - 8s 202ms/step - loss: 0.5705 - acc: 0.7101 - val_loss: 0.6741 - val_acc: 0.5660
# Epoch 5/20
# 40/40 [==============================] - 8s 201ms/step - loss: 0.5235 - acc: 0.7492 - val_loss: 0.6537 - val_acc: 0.5943
# Epoch 6/20
# 40/40 [==============================] - 8s 201ms/step - loss: 0.4687 - acc: 0.7804 - val_loss: 0.6811 - val_acc: 0.5660
# Epoch 7/20
# 40/40 [==============================] - 8s 201ms/step - loss: 0.4169 - acc: 0.8147 - val_loss: 0.7370 - val_acc: 0.5440
# Epoch 8/20
# 40/40 [==============================] - 8s 201ms/step - loss: 0.3917 - acc: 0.8291 - val_loss: 0.7528 - val_acc: 0.5660
# Epoch 9/20
# 40/40 [==============================] - 8s 206ms/step - loss: 0.3461 - acc: 0.8435 - val_loss: 0.6738 - val_acc: 0.5755
# Epoch 10/20
# 40/40 [==============================] - 8s 202ms/step - loss: 0.3188 - acc: 0.8634 - val_loss: 0.9019 - val_acc: 0.4811
# Epoch 11/20
# 40/40 [==============================] - 8s 202ms/step - loss: 0.3276 - acc: 0.8586 - val_loss: 0.8607 - val_acc: 0.5000
# Epoch 12/20
# 40/40 [==============================] - 8s 201ms/step - loss: 0.3124 - acc: 0.8730 - val_loss: 0.8306 - val_acc: 0.5031
# Epoch 13/20
# 40/40 [==============================] - 8s 201ms/step - loss: 0.2484 - acc: 0.8986 - val_loss: 0.9305 - val_acc: 0.5126
# Epoch 14/20
# 40/40 [==============================] - 8s 202ms/step - loss: 0.2352 - acc: 0.9081 - val_loss: 0.8815 - val_acc: 0.5503
# Epoch 15/20
# 40/40 [==============================] - 8s 201ms/step - loss: 0.2583 - acc: 0.9010 - val_loss: 0.9206 - val_acc: 0.5660
# Epoch 16/20
# 40/40 [==============================] - 8s 201ms/step - loss: 0.2238 - acc: 0.9097 - val_loss: 0.9697 - val_acc: 0.5409
# Epoch 17/20
# 40/40 [==============================] - 8s 201ms/step - loss: 0.1562 - acc: 0.9433 - val_loss: 1.2143 - val_acc: 0.5346
# Epoch 18/20
# 40/40 [==============================] - 8s 202ms/step - loss: 0.1749 - acc: 0.9313 - val_loss: 0.9438 - val_acc: 0.5566
# Epoch 19/20
# 40/40 [==============================] - 8s 201ms/step - loss: 0.1355 - acc: 0.9537 - val_loss: 1.1741 - val_acc: 0.5252
# Epoch 20/20
# 40/40 [==============================] - 8s 201ms/step - loss: 0.1219 - acc: 0.9457 - val_loss: 1.2779 - val_acc: 0.4654

# %%
#plotar o resultado do treino
plt.figure()
plt.plot(history.history['loss'],label='train_loss')
plt.plot(history.history['val_loss'],label='test_loss')
plt.title('Loss')
plt.legend()


plt.figure()
plt.plot(history.history['acc'],label='train_acc')
plt.plot(history.history['val_acc'],label='test_acc')
plt.title('Acurácia')
plt.legend()

# %%
# Testar com menos filtros
# criar modelo
model = get_model(IMG_HEIGHT=256, 
                  IMG_WIDTH=256, 
                  CHANNELS=1,
                  ini_filter = 8)

# Treinar o modelo
EPOCHS=20
BATCH_SIZE=32
history = model.fit(X_train, y_train , epochs=EPOCHS, 
                    batch_size = BATCH_SIZE,shuffle=True, 
                    validation_data=(X_test, y_test))
# Out:
# Epoch 1/20
# 40/40 [==============================] - 3s 43ms/step - loss: 0.7636 - acc: 0.5288 - val_loss: 0.6883 - val_acc: 0.6069
# Epoch 2/20
# 40/40 [==============================] - 1s 31ms/step - loss: 0.6535 - acc: 0.6573 - val_loss: 0.6847 - val_acc: 0.5881
# Epoch 3/20
# 40/40 [==============================] - 1s 30ms/step - loss: 0.5890 - acc: 0.6989 - val_loss: 0.6802 - val_acc: 0.5755
# Epoch 4/20
# 40/40 [==============================] - 1s 30ms/step - loss: 0.5635 - acc: 0.7069 - val_loss: 0.6790 - val_acc: 0.5629
# Epoch 5/20
# 40/40 [==============================] - 1s 30ms/step - loss: 0.5030 - acc: 0.7524 - val_loss: 0.6979 - val_acc: 0.5723
# Epoch 6/20
# 40/40 [==============================] - 1s 30ms/step - loss: 0.4314 - acc: 0.8131 - val_loss: 0.7009 - val_acc: 0.5094
# Epoch 7/20
# 40/40 [==============================] - 1s 30ms/step - loss: 0.3869 - acc: 0.8387 - val_loss: 0.7046 - val_acc: 0.5157
# Epoch 8/20
# 40/40 [==============================] - 1s 30ms/step - loss: 0.3110 - acc: 0.8746 - val_loss: 0.7844 - val_acc: 0.5629
# Epoch 9/20
# 40/40 [==============================] - 1s 30ms/step - loss: 0.2785 - acc: 0.8946 - val_loss: 0.7344 - val_acc: 0.5031
# Epoch 10/20
# 40/40 [==============================] - 1s 31ms/step - loss: 0.2468 - acc: 0.9161 - val_loss: 0.7507 - val_acc: 0.5220
# Epoch 11/20
# 40/40 [==============================] - 1s 30ms/step - loss: 0.2461 - acc: 0.9042 - val_loss: 0.8108 - val_acc: 0.5252
# Epoch 12/20
# 40/40 [==============================] - 1s 30ms/step - loss: 0.1964 - acc: 0.9305 - val_loss: 0.8718 - val_acc: 0.5535
# Epoch 13/20
# 40/40 [==============================] - 1s 31ms/step - loss: 0.1907 - acc: 0.9273 - val_loss: 0.9926 - val_acc: 0.5723
# Epoch 14/20
# 40/40 [==============================] - 1s 31ms/step - loss: 0.1638 - acc: 0.9433 - val_loss: 0.8673 - val_acc: 0.5252
# Epoch 15/20
# 40/40 [==============================] - 1s 31ms/step - loss: 0.1653 - acc: 0.9481 - val_loss: 0.9025 - val_acc: 0.5220
# Epoch 16/20
# 40/40 [==============================] - 1s 30ms/step - loss: 0.1046 - acc: 0.9633 - val_loss: 0.9158 - val_acc: 0.5252
# Epoch 17/20
# 40/40 [==============================] - 1s 30ms/step - loss: 0.0932 - acc: 0.9704 - val_loss: 1.0532 - val_acc: 0.5283
# Epoch 18/20
# 40/40 [==============================] - 1s 31ms/step - loss: 0.0971 - acc: 0.9712 - val_loss: 1.0075 - val_acc: 0.5157
# Epoch 19/20
# 40/40 [==============================] - 1s 31ms/step - loss: 0.0897 - acc: 0.9744 - val_loss: 1.1433 - val_acc: 0.5094
# Epoch 20/20
# 40/40 [==============================] - 1s 31ms/step - loss: 0.1262 - acc: 0.9473 - val_loss: 1.0110 - val_acc: 0.5220

# %%
#plotar o resultado do treino
plt.figure()
plt.plot(history.history['loss'],label='train_loss')
plt.plot(history.history['val_loss'],label='test_loss')
plt.title('Loss')
plt.legend()


plt.figure()
plt.plot(history.history['acc'],label='train_acc')
plt.plot(history.history['val_acc'],label='test_acc')
plt.title('Acurácia')
plt.legend()
